# %% [markdown]
# ## CS 237 Homework 01
#
# ### Due Thursday January 27th at Midnight (1 minute after 11:59pm) in Gradescope (with grace period of 6 hours)
# ### Homeworks may be submitted up to 24 hours late with a 10% penalty (same grace period)
#
# In this first homework, we will review some material from CS 131 and MA 123 which you will need to be successful in CS 237.  In addition, you will become familiar with various methods of displaying the results of probability experiments graphically in Python using Jupyter notebooks and Matplotlib.
#
#
#
# It would be an excellent idea to review your CS 131 text and/or notes before starting this homework. Readings and practice problems are listed on the class schedule each week, and you should do these, as well as attend discussions and work the practice problems there.
# Probability is not a spectator sport!
#
#
# Submit your homework by filling in this notebook with your solutions; use Latex if possible, as your answers will be more easily understood. A notebook of Latex examples is posted in Piazza Resources. **Be sure to click on Run All and verify that everything works as you intended,** and then upload the file to Gradescope.
#
# If you do not Run All and your solutions are not visible, you will be given *one* homework regrade where the grader will download your file and run it, but after that we will grade only what we can see, and will not run the files.
#
#
# ### Reminder
#
# - Collaboration in understanding the problems is permitted, but you must write the solutions *by yourself without assistance*, and be ready to explain them orally to the instructor if asked.
#
# - You must also identify your collaborators and whether you gave help, received help, or worked something out together. Getting solutions from outside sources such as the Web or students not enrolled in the class is strictly forbidden.
#
# - Please refer to the general information handout for the full homework policy and options.

# %% [markdown]
# **Collaborators:** (your answer here)

# %% [markdown]
# ### Problem 0. (No credit, but you MUST do this.)
#
# <ol>
# <li> You should have received an enrollment email from Piazza and from Gradescope, please verify that you can access the sites and are enrolled:
#
# https://piazza.com/bu/spring2022/cascs237/home
# https://www.gradescope.com/
#
#
# <li> <b>Register for Top Hat.</b> If you already have an account,
#
# https://app.tophat.com/e/413437
#
# will take you to our course. Otherwise, follow the link in the email invitation you received or:
# <ul>
#   <li>Go to https://app.tophat.com/register/student
#   <li>Click "Search by school" and input Boston University;
#     <li> Search for our course with the following join code: <b>413437</b>
#    <li> If a paid subscription is required, it will be listed at checkout when you enroll in our Top Hat course.
#    <li> Should you require assistance with Top Hat at any time please contact their Support Team directly by way of email (support@tophat.com), the in-app support button, or by calling 1-888-663-5491. Specific user information may be required by their technical support team when troubleshooting issues.
# </ul>
#
# <li><b>Read and sign the Collaboration and Honesty Policy and submit it on Gradescope.</b> We will not grade your homework until you complete this step.
#
# <li> <b>Nameplate:</b> Please print out (or make by hand) a nameplate with your name and bring it to every discussion. A template is available at the bottom of the course web page.
#
# <li> Check out the following links and resources and <b>bookmark them right away:</b>
#
#  <ul>
# <li>  Course webpage:
#
# https://cs-people.bu.edu/sofya/cs237/;
#
# <li>  Course textbooks:
#
# Mathematics for Computer Science:
# https://cs-people.bu.edu/aene/cs237fa21/mcs.pdf
#
# H. Pishro-Nik, Introduction to probability, statistics, and random processes: https://www.probabilitycourse.com,
#
#
# <li> As needed, here is a great supplementary textbook to review proof techniques:
#
# Richard Hammack, Book of Proof:
#
# http://www.people.vcu.edu/~rhammack/BookOfProof/.
#  </ul>
#
# </ol>

# %% [markdown]
# ## Analytical Problems
#
# For the following, please type your answer in the cell provided.

# %% [markdown]
# ## Problem 1: Counting review (10 pts)
# These are worth 1 point each, except 2 points for each of the last two parts.
#
# This problem is motivated by Wordle, a popular word game. If you haven't yet been consumed by the Wordle mania, you can read the rules here:
#
# https://www.powerlanguage.co.uk/wordle/.
#
#
# For this problem, a "word" is a string of English letters, even if it is gibberish. English has 26 letters and
# 5 vowels $a,e,i,o,u$
# (we don't include $y$) and 21 consonants.
#
# For each part below, write a brief explanation using complete sentences. Express your answers as tidy products of integers or powers of integers. You do not need to calculate the final results, which in most cases are very large.
#
#
# (A)  How many 5-letter "words" are there?
#
# there are $$26 *26*26 *26 *26$$ (or 26\*5) words possibilities
#
# (B) How many 5-letter "words" are there, where all letters are distinct?
# $$26* 25* 24* 23* 22$$
#
# (C) How many 5-letter "words" begin with a consonant and have vowels in positions 2 and 4?
# $$21* 5* 26* 5* 26$$
#
# (D) The same question as in the previous part, but with the requirement that all letters are distinct.
#
# $$21* 5* 20* 4* 19 \over 5!$$
#
#
# (E) In how many ways can you choose 5 distinct letters for the word of the day (without ordering them)
# $$26* 25* 24* 23* 22$$
#
# (F) In how many ways can you choose 5 distinct (unordered) letters if you want exactly two of them to be vowels?
# $$21* 20* 19* 5* 4$$
#
# (G) Suppose you type in "daisy" and get that $i$ is green, $s$ is brown, and the remaining letters are gray. How many 5-letter "words" remain in the game.
#
# ![Screen%20Shot%202022-01-19%20at%2012.32.52%20PM-2.png](attachment:Screen%20Shot%202022-01-19%20at%2012.32.52%20PM-2.png)
#
# *Hint G:* First calculate how many words remain in the game without insisting they have an $s$ in positions 1, 2, or 5. Then subtract the number of words in the previous count that do not contain an $s$.
# $$26*26*1*25*26 - 25$$
# $$25* 25* 1* 24* 25$$
# (H) The same question as in part (G), except that both $i$ and $s$ are brown, and no letters are green.
#
# $$26* 26* 25* 25* 26$$
#
# *Hint H:* Use the Inclusion-Exclusion principle.

# %% [markdown]
# **Solution:**

# %% [markdown]
# ## Problem 2  (Proof techniques review) (15 pts)
#
# (A) **Direct proof:** Show that the sum of any three consecutive integers is divisible by 3.
#
#
#
# (B) **Proof by contradiction:** Prove by contradiction that if
# $x$ is a real solution to $x^5+3x^2+9x+2 = 0$, then $x$ must be negative.
#
# *Think about it, but don't submit:* Why can't we say that $x$ is a solution to this equation if and only if $x$ is negative?
#
# (C) **Induction:** Find the error in the following proof that all BU students have the same GPA. Indicate the **first sentence in the proof** that is incorrect. (There must be an incorrect statement in the proof, since the claim is wrong.)
#
# *Claim:* In every set of $n$ BU students, all students have the same GPA.
#
# *Proof:* By induction on $n$.
#
# **Base case:** $n=1$. In every set containing just one BU student, all students clearly have the same GPA.
#
# **Induction step:** For $k\geq 1$ assume that the claim holds for $n=k$ and prove that it holds for $n=k+1$. Take any set $S$ of $k+1$ BU students. Remove one student from this set to obtain the set $S_1$ with $k$ students. By the induction hypothesis, all students in $S_1$ have the same GPA. Now replace the removed student and remove a different one to obtain the set $S_2$. By the same argument, all students in $S_2$ have the same GPA. Therefore, all the students in $S$ must have the same GPA.
#
#
# (D) **Induction:** Prove by induction that
# $$\frac 1 {1\cdot 2}+\frac 1 {2\cdot 3}+\dots +\frac 1 {n\cdot (n+1)}
# =\frac n {n+1}.
# $$

# %% [markdown]
# **Solution:**
#
# A.)the sum of any three consetcive integers is equivanlent to the statement n + n+1+ n+2 which is also equivalent to 3n+3 by factoring out the 3 the result is 3(n-1) which is now divisible by 3 leaving only n+1 which is an odd number
#
# B.) for the proof of contradiction we can assume that in the given statement above that $x$ is a real solution to $x^5+3x^2+9x+2 = 0$, then $x$ is actually positive rather than negative, but if this were true than the reuslt would always be more than 0 cant be true since it directly contradict the equations, so if x = 0 than the result from plugging it in would be 2 rather than 0, proving that the statement is true x must be negative to hold true
#
# C.)the first sentence incorrect in the proof is the base case because the assumption that because one student has a certain gpa so all others must have the same gpa doesn't make any sense and has no backing behind it, its an assumption that suddennly now proves each case with no explaination because if the first person has one gpa under that logic you wouldn't have to check any other cases, all the students would have that gpa which isn't nececsarily true
#
# D.)
#
# Base case is n = 1 $$\frac 1 {1(1+1)} = \frac1 {(1+1)}$$ which is equivalent to $$\frac1 2 = \frac1 2$$
#
# the induction step is when k $\ge$ 1 we will assume that the claim is true for both n=k and prove it does for n= k+1
#
# $$\frac k {(k+1)} + \frac1 {k(k+1)(k+2)}$$
# which if we cross multiply to get a common demoninator we get
#
# $$\frac {k(k+2)} {(k+1)(k+2)}+ \frac1 {(k+1)(k+2)}$$
#
# if you multiply it out and then factor you end up with
#
# $$\frac {(k+1)(k+1)} {(k+1)(k+2)}$$
# which then can be simplified to just
#
# $$\frac {(k+1)} {(k+2)}$$
# which shows that in terms of k, the statement is true $$\frac n {n+1} $$

# %% [markdown]
# ## Problem Three (Calculus Refresher) (10 pts)
#
# (A) Give the inverse of the following function: $f(x) = 4(x-3)^5 + 21$.
#
# (B) Without using a calculator, give the exact result of the following expression: $\ln e^5$.
#
# (C) Which of the following is the graph of the function $g(x) = 3^{1 + 2x}$?

# %% [markdown]
# (C1)
# ![Screen%20Shot%202022-01-19%20at%209.22.14%20PM.png](attachment:Screen%20Shot%202022-01-19%20at%209.22.14%20PM.png)

# %% [markdown]
# (C2)
# ![Screen%20Shot%202022-01-19%20at%209.21.52%20PM.png](attachment:Screen%20Shot%202022-01-19%20at%209.21.52%20PM.png)

# %% [markdown]
# (C3)
#
# ![Screen%20Shot%202022-01-19%20at%209.21.37%20PM.png](attachment:Screen%20Shot%202022-01-19%20at%209.21.37%20PM.png)

# %% [markdown]
# (C4)
#
# ![Screen%20Shot%202022-01-19%20at%209.21.17%20PM.png](attachment:Screen%20Shot%202022-01-19%20at%209.21.17%20PM.png)

# %% [markdown]
# (D) For $f(x) = {9\over(x-3)^5}$, evaluate:
#
# (D1) $$\lim_{x\rightarrow 3^-} f(x).$$
# (D2) $$\lim_{x\rightarrow 3^+} f(x).$$
# (D3) $$\lim_{x\rightarrow 3} f(x).$$
#
# (E) Find the derivative of $f(x) = 4x^7 - 3x^{-7} + 9x$.
#
# (F)  Find the derivative of $f(x) = (4x^2 - 3x + 2)^{-2}$.
#
# (G) Calculate this definite integral, showing all work:
#
# $$\int_0^2 3x^2-4x + 2\, dx.$$

# %% [markdown]
# **Solution:**
#
# A.)$$f(x)^{-1} =  \sqrt[5]{(x-21/4)}+3 $$
#
# B.)$$1 + 5 + (5^2)/2! + (5^3)/3! + (5^4)/4! + (5^5)/5  =  1+ 5 + 25/2 + 125/6 + 625/24 + 3125/120 $$
#
#
# C.)C4 is the correct graph
#
# D.)
#
#     D1.)eveluates to -infinity
#
#     D2.)evaluates to infinity
#
#     D3.)the limit divererges
#
# E.) the derivative of $f(x) = 28x^6+21x^{-6}+9$
#
# F.)the derivative of $fx) = - 2(8x-3)/ ( 4x^2-3x+2)^3$
#
# G.)$$(3\int x^2\, dx)- (4\int x\, dx) + (2\int 1\, dx) $$
# $$ \int x^2\, dx = x^3/3$$
# $$\int x\, dx  = x^2/2$$
# $$\int 1\, dx = x $$
#
# plug each integral result back into the statements and it results in
#
# $$x^3 - 2x^2+2x + C$$

# %% [markdown]
# ### Getting Started with Data Visualization in Jupyter Notebooks
#
# In this homework, we will begin our study of probability in computing by exploring various ways of displaying data, especially data created by random processes. We shall use a library <code>numpy.random</code> (imported in the next code cell) to generate random numbers and display the results.
#
# If you need a refresher on Python, please download and work through the <code>PythonForCS237.ipynb</code> notebook from the Resources section in Piazza, in addition to this homework. You may also wish to look at the
# video on Professor Snyder's YouTube channel, where he talks through the notebook
# and explains the concepts:
#
# https://www.youtube.com/channel/UCfSqNB0yh99yuG4p4nzjPOA/videos
#
# Other tutorials, on Markdown (for writing text), Latex, and Numpy, may be found
# here:
#
# https://www.cs.bu.edu/fac/snyder/cs237/tutorials/
#
# Some of these have video tutorials on Snyder's YouTube channel as well.

# %%
# Here are some imports which you may find useful!

import numpy as np                # arrays and functions which operate on array
import matplotlib.pyplot as plt   # normal plotting

from numpy.random import seed, randint

# NOTE: You may not use any other libraries than those listed here without explicit permission.

# %% [markdown]
# # Problem 5: Displaying the results of a random experiment using histograms (5 pts)
#
# You must write a function which simulates the rolling of a standard six-sided die 10,000
# times, reporting the result using a histogram.  Please read the appropriate section of the `pythonForCS237.ipynb` notebook if you are unfamiliar with histograms and how to produce them.
#
# The details about rolling a die are straight-forward:
# - The outcomes are $\{1,2,3,4,5,6\}$ (we will call this the *sample space* next week);
# - The probability of any particular outcome is $\frac{1}{6}$.
# - If we record the outcome for a large number of experiments, we would expect the number of outcomes to be "evenly distributed" (next week we'll call this "equi-probable"). In other words, for a large number of trials, we would expect the probability of each outcome $k\in \{1,2,3,4,5,6\}$ to be
#
# $$\frac{\text{number of times we observed a value } k}{\texttt{num_trials}} \approx \frac{1}{6}$$
#
# First, we will learn how to generate random integer values.

# %%
# Demo of randint(lo,hi), which generates a random integer from the sequence 
# [lo,lo+1,...,hi-1].  Note carefully that the lower bound is inclusive and the upper bound is non-exclusive, just
# like the range(...)  function in Python. 

# Run this cell a few times!

randint(0,4)
# Out:
# 2

# %%
# You can also ask it for an array of a given size, since it is a Numpy function:

randint(0,4,10)
# Out:
# array([0, 1, 2, 1, 3, 2, 0, 3, 0, 1])

# %%
# Ok, your turn!

# Write a function which simulates rolling a fair die num_trials times, 
#. i.e., a number is selected from 
# (1,2,3,4,5,6) with equal probability num_trials times. By default, 
# num_trials is set to 10000.

seed(0)      # this will verify that the solution is the same every time, for grading

# Return a list off 10,000 outcomes

def roll_die(num_trials = 10000):  # Notice the use of a default value for the parameter here
    
    # your code here
    return []     # just to get it to compile, change this

example_trials = roll_die()

# test
print(example_trials[:10])
# Out:
# []

# %% [markdown]
# Next, provide code in the next cell which will show the result of this experiment. Be sure to provide appropriate values for `bins` which give the edges of the six bins.
#
# Your result should look  like this:
#
# ![Screen%20Shot%202022-01-19%20at%209.52.21%20PM.png](attachment:Screen%20Shot%202022-01-19%20at%209.52.21%20PM.png)

# %%
# Solution: 
import numpy as np                
import matplotlib.pyplot as plt   
from numpy.random import seed, randint

seed(0)

def roll_die(num_trials = 10000): 
    arr = randint(1,7,num_trials)
    return arr     

roll = roll_die()

print(example_trials[:10])

plt.figure(num=None, figsize=(8, 6))
plt.hist( roll,bins = [1,2,3,4,5,6], edgecolor='black')


plt.title('Histogram of die roll experiement 10,000 trials')
plt.xlabel("Outcomes")
plt.ylabel("Frequency")
plt.show()
# Out:
# []

# %% [markdown]
# # Problem 6: Displaying the result of an experiment using a probability distribution (5 pts)
#
# You will now do the same thing you did in the previous problem, but instead of rolling one die and recording the value, you will simulate rolling 2 dice and recording their sum. For example, the first die shows up as a 3, and the second die shows up as a 1, the sum (and the outcome we store) would be 4.
#
# One more change:  instead of reporting the result using a histogram, we will use a bar chart, and record the frequency of each outcome (2 -- 12) and give the decimal fraction of the total trials (trial = one throw of the pair of dice); this
# kind of display is called a "probability distribution" and will be a core concept in the course. Essentially, we are dividing the y-axis by the number of trials to obtain
# the percentage (out of 1.0) instead of the raw frequency of each outcome.
#
#
# TO DO:  Complete the function stub below and then demonstrate by printing out a bar chart of the probabilities. You should read the appropriate section of `PythonForCs237.ipynb` if you are unfamiliar with bar charts.
#
# Hint: A good way to do this is to use a Python dictionary to record the frequency of each outcome.  Another good way would be a list. Don't use a separate variable for each outcome!
#
# Optional: You can implement `sum_of_two_dice` in one line using list comprehensions and the Python function
# `Count` from the `collections` library (Google it!).

# %%
import numpy as np                
import matplotlib.pyplot as plt   
from numpy.random import seed, randint
from collections import Counter

seed(0)

def roll_die(num_trials = 10000): 
    arr = randint(1,7,num_trials)
    return arr     

roll1 = roll_die()
roll2 = roll_die()
roll3 = []

for i in range(10000):
    roll3.append(roll1[i]+roll2[i])
ans = Counter(roll3)

plt.figure(num=None, figsize=(8, 6))
keys = ans.keys()
values = ans.values()
plt.bar(keys, values)
plt.title('Die roll Sum Bar Chart')
plt.xlabel("The Sum Values")
plt.ylabel("Occurances")
plt.show()
